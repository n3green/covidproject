# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('dados/casos.csv')

# %%
nome_arquivo = 'dados/casos.csv'
df = pd.read_csv(nome_arquivo)

# %%
df.head()
# Out:
#          city  city_ibge_code        date  epidemiological_week  \
# 0  Rio Branco       1200401.0  2020-03-17                202012
# 1         NaN            12.0  2020-03-17                202012
# 2  Rio Branco       1200401.0  2020-03-18                202012
# 3         NaN            12.0  2020-03-18                202012
# 4  Rio Branco       1200401.0  2020-03-19                202012
#
#    estimated_population  estimated_population_2019  is_last  is_repeated  \
# 0              413418.0                   407319.0    False        False
# 1              894470.0                   881935.0    False        False
# 2              413418.0                   407319.0    False        False
# 3              894470.0                   881935.0    False        False
# 4              413418.0                   407319.0    False        False
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3853648 entries, 0 to 3853647
# Data columns (total 18 columns):
#  #   Column                                         Dtype
# ---  ------                                         -----
#  0   city                                           object
#  1   city_ibge_code                                 float64
#  2   date                                           object
#  3   epidemiological_week                           int64
#  4   estimated_population                           float64
#  5   estimated_population_2019                      float64
#  6   is_last                                        bool
#  7   is_repeated                                    bool
#  8   last_available_confirmed                       int64
#  9   last_available_confirmed_per_100k_inhabitants  float64
#  10  last_available_date                            object
#  11  last_available_death_rate                      float64
# ...

# %%
df.describe(include='all')

# %%
df.isnull().sum()

# %%
df.fillna(value={'city':'Não informado', 'state':'Não informado', 'country':'Não informado', 'city_ibge_code':'Não informado', 'estimated_population':'Não informado', 'estimated_population_2019':'Não informado', 'last_available_confirmed_per_100k_inhabitants': 'Não informado'})
# Out:
#                   city city_ibge_code        date  epidemiological_week  \
# 0           Rio Branco      1200401.0  2020-03-17                202012
# 1        Não informado           12.0  2020-03-17                202012
# 2           Rio Branco      1200401.0  2020-03-18                202012
# 3        Não informado           12.0  2020-03-18                202012
# 4           Rio Branco      1200401.0  2020-03-19                202012
# ...                ...            ...         ...                   ...
# 3853643       Tupirama      1721257.0  2022-03-27                202213
# 3853644     Tupiratins      1721307.0  2022-03-27                202213
# 3853645   Wanderlândia      1722081.0  2022-03-27                202213
# 3853646        Xambioá      1722107.0  2022-03-27                202213
# 3853647  Não informado           17.0  2022-03-27                202213
#
#         estimated_population estimated_population_2019  is_last  is_repeated  \
# ...

# %%
shape_before = df.shape[0]
shape_curr = df.dropna (how='all').shape[0]
print ('{} linhas foram apagadas, o que equivale a {}%'.format(shape_before-shape_curr, 100-(shape_before-shape_curr)))
